# %%
from pyresparser import ResumeParser
import os
from docx import Document
import pandas as pd
import spacy
import unicodedata
import string
import joblib
import re

# %%
# Load the spacy library for text cleaning
nlp = spacy.load('en_core_web_sm')

# %%
# Loading the saved model
rf_clf = joblib.load('rf_clf.pkl')
# Out:
# C:\Users\Ellefson\miniconda3\envs\cv-screen\lib\site-packages\sklearn\base.py:338: UserWarning: Trying to unpickle estimator CountVectorizer from version 1.0.1 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   UserWarning,
# C:\Users\Ellefson\miniconda3\envs\cv-screen\lib\site-packages\sklearn\base.py:338: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.0.1 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   UserWarning,
# C:\Users\Ellefson\miniconda3\envs\cv-screen\lib\site-packages\sklearn\base.py:338: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 1.0.1 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   UserWarning,
# C:\Users\Ellefson\miniconda3\envs\cv-screen\lib\site-packages\sklearn\base.py:338: UserWarning: Trying to unpickle estimator Pipeline from version 1.0.1 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   UserWarning,

# %%
filed = input()

# %%
try:
    doc = Document()
    with open(filed, 'r') as file:
        doc.add_paragraph(file.read())
    doc.save('text.docx')
    data = ResumeParser('text.docx').get_extracted_data()
    print(data['skills'])
except:
    data = ResumeParser(filed).get_extracted_data()
    print(data['skills'])
# Out:
# C:\Users\Ellefson\AppData\Roaming\Python\Python37\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# ['Matlab', 'Scripting', 'Cms', 'Docker', 'Technical', 'Numpy', 'Html5', 'Engineering', 'Mobile', 'Responses', 'Python', 'Cloud', 'Operating systems', 'Shell', 'Aws', 'Database', 'Pandas', 'Specifications', 'Matrix', 'Technical skills', 'Unix', 'Machine learning', 'Php', 'English', 'Computer science', 'Research', 'Django', 'Programming', 'Statistics', 'Information technology', 'Email', 'Software engineering', 'Testing', 'Mysql', 'Javascript', 'Beautifulsoup', 'Java']

# %%
data
# Out:
# {'name': 'Sachin Pokharel',
#  'email': 'sachinwork33@gmail.com',
#  'mobile_number': '673-2437154',
#  'skills': ['Matlab',
#   'Scripting',
#   'Cms',
#   'Docker',
#   'Technical',
#   'Numpy',
#   'Html5',
#   'Engineering',
#   'Mobile',
#   'Responses',
#   'Python',
#   'Cloud',
#   'Operating systems',
#   'Shell',
#   'Aws',
#   'Database',
#   'Pandas',
#   'Specifications',
#   'Matrix',
#   'Technical skills',
#   'Unix',
#   'Machine learning',
#   'Php',
#   'English',
#   'Computer science',
#   'Research',
#   'Django',
#   'Programming',
#   'Statistics',
#   'Information technology',
#   'Email',
#   'Software engineering',
#   'Testing',
#   'Mysql',
#   'Javascript',
#   'Beautifulsoup',
#   'Java'],
#  'college_name': None,
#  'degree': ['Bachelor of Technology in Information Technology (B.Tech IT)   \nIndian Institute of Information Technology'],
#  'designation': None,
#  'experience': ['08/2017 – 07/2018',
#   'Assistant Web Developer',
#   'Code Sastra Pvt. Ltd, Pokhara, Nepal',
#   'Responsible for managing various stages of Web Development',
#   '\uf0b7  Gather and refine specifications & requirements based on technical needs.',
#   '\uf0b7  Create, edit, manage and maintain CMS-based web sites.',
#   '\uf0b7  Code modifications using HTML5; CSS3; JavaScript; PHP.'],
#  'company_names': None,
#  'no_of_pages': 3,
#  'total_experience': 0.0}

# %%
datas = []
datas.append(data)

# %%
cleaned_data = {x.replace('_', ' '): v
    for x, v in data.items()}

# %%
def clean_text(text):
    #print(f'Text before Cleaning: {text}')
    # Text to lowercase
    #text = text.lower()
    # Remove URL from text
   # text = re.sub(r"http\S+", "", text)
    # Remove Numbers from text
   # text = re.sub(r'\d+', '', text)
    # Convert the unicode string to plain ASCII
    #text = unicode_to_ascii(text)
    # Remove Punctuations
    text = re.sub(r'[^\w\s]','', text) 
    #text = remove_punct(text)
    # Remove StopWords
   # text = remove_stopwords(text)
    # Remove empty spaces
   # text = text.strip()
    # \s+ to match all whitespaces
    # replace them using single space " "
   # text = re.sub(r"\s+", " ", text)    
    #print(f'Text after Cleaning: {text}')
    return text

# %%
cleaned_data.values()
# Out:
# dict_values(['Sachin Pokharel', 'sachinwork33@gmail.com', '673-2437154', ['Matlab', 'Scripting', 'Cms', 'Docker', 'Technical', 'Numpy', 'Html5', 'Engineering', 'Mobile', 'Responses', 'Python', 'Cloud', 'Operating systems', 'Shell', 'Aws', 'Database', 'Pandas', 'Specifications', 'Matrix', 'Technical skills', 'Unix', 'Machine learning', 'Php', 'English', 'Computer science', 'Research', 'Django', 'Programming', 'Statistics', 'Information technology', 'Email', 'Software engineering', 'Testing', 'Mysql', 'Javascript', 'Beautifulsoup', 'Java'], None, ['Bachelor of Technology in Information Technology (B.Tech IT)   \nIndian Institute of Information Technology'], None, ['08/2017 – 07/2018', 'Assistant Web Developer', 'Code Sastra Pvt. Ltd, Pokhara, Nepal', 'Responsible for managing various stages of Web Development', '\uf0b7  Gather and refine specifications & requirements based on technical needs.', '\uf0b7  Create, edit, manage and maintain CMS-based web sites.', '\uf0b7  Code modifications using HTML5; CSS3; JavaScript; PHP.'], None, 3, 0.0])

# %%
df = pd.DataFrame(cleaned_data.values(), columns=["content"])

# %%
df
# Out:
#                                               content
# 0                                     Sachin Pokharel
# 1                              sachinwork33@gmail.com
# 2                                         673-2437154
# 3   [Matlab, Scripting, Cms, Docker, Technical, Nu...
# 4                                                None
# 5   [Bachelor of Technology in Information Technol...
# 6                                                None
# 7   [08/2017 – 07/2018, Assistant Web Developer, C...
# 8                                                None
# 9                                                   3
# 10                                                0.0

# %%
df["content"] = df.content.apply(lambda x: clean_text(str(x)))

# %%
df
# Out:
#                                               content
# 0                                     Sachin Pokharel
# 1                                 sachinworkgmail.com
# 2                                                   -
# 3   'Matlab', 'Scripting', 'Cms', 'Docker', 'Techn...
# 4                                                None
# 5   'Bachelor of Technology in Information Technol...
# 6                                                None
# 7   '  ', 'Assistant Web Developer', 'Code Sastra ...
# 8                                                None
# 9
# 10                                                  .

# %%
# Out:
# name
# email
# mobile_number
# skills
# college_name
# degree
# designation
# experience
# company_names
# no_of_pages
# total_experience

# %%
# Turn a Unicode string to plain ASCII, thanks to https://stackoverflow.com/a/518232/2809427
def unicode_to_ascii(s):
    all_letters = string.ascii_letters + " .,;'-"
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
        and c in all_letters
    )

# Remove Stop Words
def remove_stopwords(text):
    doc = nlp(text)
    return " ".join([token.text for token in doc if not token.is_stop])

# %%
def clean_text(text):
    #print(f'Text before Cleaning: {text}')
    # Text to lowercase
    text = text.lower()
    # Remove URL from text
    text = re.sub(r"http\S+", "", text)
    # Remove Numbers from text
    text = re.sub(r'\d+', '', text)
    # Convert the unicode string to plain ASCII
    text = unicode_to_ascii(text)
    # Remove Punctuations
    text = re.sub(r'[^\w\s]','', text) 
    #text = remove_punct(text)
    # Remove StopWords
    text = remove_stopwords(text)
    # Remove empty spaces
    text = text.strip()
    # \s+ to match all whitespaces
    # replace them using single space " "
    text = re.sub(r"\s+", " ", text)    
    #print(f'Text after Cleaning: {text}')
    return text

# %%
clean_text(data)
# Out:
# 'sachin pokharel email sachinworkgmailcom mobilenumber skills cms docker engineering aws research html technical machine learning statistics php responses database pandas cloud testing java matrix technical skills unix mobile shell computer science operating systems information technology programming numpy software engineering specifications beautifulsoup javascript scripting english django email python mysql matlab collegename degree bachelor technology information technology btech nindian institute information technology designation experience assistant web developer code sastra pvt ltd pokhara nepal responsible managing stages web development ufb gather refine specifications requirements based technical needs ufb create edit manage maintain cmsbased web sites ufb code modifications html css javascript php companynames noofpages totalexperience'

# %%
# Prediction
guess = False
while not guess:
    my_tweet = clean_text(data)
    prediction = rf_clf.predict([my_tweet])
    print(prediction)
# Out:
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ['Python Developer']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12336\1178342399.py in <module>
#       2 guess = False
#       3 while not guess:
# ----> 4     my_tweet = clean_text(data)
#       5     prediction = rf_clf.predict([my_tweet])
#       6     print(prediction)
#
# ~\AppData\Local\Temp\ipykernel_12336\3316083834.py in clean_text(text)
#      13     #text = remove_punct(text)
#      14     # Remove StopWords
# ---> 15     text = remove_stopwords(text)
#      16     # Remove empty spaces
#      17     text = text.strip()
#
# ~\AppData\Local\Temp\ipykernel_12336\1589041678.py in remove_stopwords(text)
#      10 # Remove Stop Words
#      11 def remove_stopwords(text):
# ---> 12     doc = nlp(text)
#      13     return " ".join([token.text for token in doc if not token.is_stop])
#
# ~\AppData\Roaming\Python\Python37\site-packages\spacy\language.py in __call__(self, text, disable, component_cfg)
#     443             if not hasattr(proc, "__call__"):
#     444                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 445             doc = proc(doc, **component_cfg.get(name, {}))
#     446             if doc is None:
#     447                 raise ValueError(Errors.E005.format(name=name))
#
# pipes.pyx in spacy.pipeline.pipes.Tagger.__call__()
#
# pipes.pyx in spacy.pipeline.pipes.Tagger.predict()
#
# ~\AppData\Roaming\Python\Python37\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# ~\AppData\Roaming\Python\Python37\site-packages\thinc\neural\_classes\feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# ~\AppData\Roaming\Python\Python37\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# ~\AppData\Roaming\Python\Python37\site-packages\thinc\api.py in predict(seqs_in)
#     308     def predict(seqs_in):
#     309         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
# --> 310         X = layer(layer.ops.flatten(seqs_in, pad=pad))
#     311         return layer.ops.unflatten(X, lengths, pad=pad)
#     312
#
# ~\AppData\Roaming\Python\Python37\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# ~\AppData\Roaming\Python\Python37\site-packages\thinc\neural\_classes\feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# ~\AppData\Roaming\Python\Python37\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# ~\AppData\Roaming\Python\Python37\site-packages\thinc\neural\_classes\model.py in predict(self, X)
#     129
#     130     def predict(self, X):
# --> 131         y, _ = self.begin_update(X, drop=None)
#     132         return y
#     133
#
# ~\AppData\Roaming\Python\Python37\site-packages\thinc\api.py in uniqued_fwd(X, drop)
#     374             keys = keys.get()
#     375         uniq_keys, ind, inv, counts = numpy.unique(
# --> 376             keys, return_index=True, return_inverse=True, return_counts=True
#     377         )
#     378         X_uniq = layer.ops.xp.ascontiguousarray(X[ind])
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# ~\miniconda3\envs\cv-screen\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     270     ar = np.asanyarray(ar)
#     271     if axis is None:
# --> 272         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     273         return _unpack_tuple(ret)
#     274
#
# ~\miniconda3\envs\cv-screen\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     328
#     329     if optional_indices:
# --> 330         perm = ar.argsort(kind='mergesort' if return_index else 'quicksort')
#     331         aux = ar[perm]
#     332     else:
#
# KeyboardInterrupt:
